# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import seaborn as sns
sns.set()

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df = pd.read_csv("data/land_train.csv")

# %%
print(df.columns)
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'I1', 'I2', 'I3', 'I4', 'I5', 'I6',
#        'target'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   X1             X2             X3             X4  \
# count  110000.000000  110000.000000  110000.000000  110000.000000
# mean      505.820582     778.290627     819.375336    1752.844418
# std       428.347173     529.490028     674.422188     693.583645
# min         0.000000      79.000000       0.000000      77.000000
# 25%       172.000000     333.000000     211.000000    1209.000000
# 50%       540.000000     809.500000     817.000000    1785.000000
# 75%       699.000000    1022.000000    1237.000000    2148.000000
# max      9346.000000    9615.000000    9877.000000    9316.000000
#
#                   X5             X6             I1             I2  \
# count  110000.000000  110000.000000  110000.000000  110000.000000
# mean     1078.027418     739.470318       0.384085      -0.712814
# std       868.842300     797.061740       0.387576       0.472998
# min        52.000000      25.000000      -0.517672      -1.566332
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=110000, step=1)

# %%
features = ['X1','X2','X3','X4','X5','X6','I1','I2','I3','I4','I5','I6']
df[features].hist(figsize=(20, 20));

# %%
sns.boxplot(x='X1',data=df)

# %%
data = []

# Create a box trace for each genre in our dataset
for target_classes in df.target.unique():
    data.append(
        go.Box(y=df[df.target == target_classes].X6, name=str(target_classes))
    )
    
# Visualize
iplot(data, show_link=False)
# Out:
# <div id="72b8e4ac-5201-46db-98d5-2eb621f83d86" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("72b8e4ac-5201-46db-98d5-2eb621f83d86", [{"name": "1", "y": [115, 89, 45, 84, 130, 46, 88, 134, 53, 105, 164, 81, 139, 191, 453, 680, 48, 98, 156, 202, 275, 305, 422, 434, 34, 55, 94, 135, 189, 223, 304, 334, 319, 308, 356, 389, 382, 52, 75, 93, 107, 131, 173, 300, 328, 383, 441, 69, 97, 120, 144, 357, 475, 497, 56, 89, 57, 65, 64, 49, 40, 65, 83, 88, 43, 60, 81, 103, 120, 161, 63, 94, 115, 124, 132, 81, 129, 132, 124, 116, 123, 74, 124, 146, 61, 109, 151, 155, 25, 69, 107, 115, 97, 73, 45, 47, 57, 75, 90, 86, 70, 47, 58, 43, 36, 51, 70, 70, 51, 76, 51, 87, 47, 97, 173, 43, 75, 118, 151, 41, 60, 84, 92, 44, 67, 112, 36, 53, 77, 41, 55, 63, 1116, 1336, 1487, 1263, 895, 708, 634, 1618, 1736, 1454, 1331, 1193
# ...

# %%
df.iloc[:,12].value_counts()
# Out:
# 1    50000
# 2    30000
# 3    20000
# 4    10000
# Name: target, dtype: int64
